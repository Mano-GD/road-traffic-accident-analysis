# %%
import pandas as pd

# %%
df=pd.read_excel('Accident analysis.xlsx')
df.head()
# Out:
#    Accident_Index Accident Date Day_of_Week              Junction_Control  \
# 0               1    2021-06-27    Saturday  Data missing or out of range
# 1               2    2021-07-04    Saturday  Data missing or out of range
# 2               3    2021-08-06    Thursday  Data missing or out of range
# 3               4    2021-01-02      Friday      Give way or uncontrolled
# 4               5    2021-01-05      Monday  Data missing or out of range
#
#                        Junction_Detail Accident_Severity   Latitude  \
# 0  Not at junction or within 20 metres             Fatal  55.835218
# 1  Not at junction or within 20 metres             Fatal  55.855145
# 2  Not at junction or within 20 metres             Fatal  55.835794
# 3              T or staggered junction            Slight  54.473619
# 4  Not at junction or within 20 metres            Slight  54.537690
#
#          Light_Conditions Local_Authority_(District) Carriageway_Hazards  ...  \
# ...

# %%
df.head(2).T
# Out:
#                                                               0  \
# Accident_Index                                                1
# Accident Date                               2021-06-27 00:00:00
# Day_of_Week                                            Saturday
# Junction_Control                   Data missing or out of range
# Junction_Detail             Not at junction or within 20 metres
# Accident_Severity                                         Fatal
# Latitude                                              55.835218
# Light_Conditions                                       Daylight
# Local_Authority_(District)                      North Larkshire
# Carriageway_Hazards                                         NaN
# Longitude                                             -3.912012
# Number_of_Casualties                                          1
# Number_of_Vehicles                                            2
# Police_Force                                        Strathclyde
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30429 entries, 0 to 30428
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Accident_Index              30429 non-null  int64
#  1   Accident Date               30429 non-null  datetime64[ns]
#  2   Day_of_Week                 30429 non-null  object
#  3   Junction_Control            30429 non-null  object
#  4   Junction_Detail             30429 non-null  object
#  5   Accident_Severity           30429 non-null  object
#  6   Latitude                    30429 non-null  float64
#  7   Light_Conditions            30429 non-null  object
#  8   Local_Authority_(District)  30429 non-null  object
#  9   Carriageway_Hazards         341 non-null    object
#  10  Longitude                   30429 non-null  float64
#  11  Number_of_Casualties        30429 non-null  int64
#  12  Number_of_Vehicles          30429 non-null  int64
# ...

# %%
df1=df.iloc[:,1:]

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
df1.isnull().sum()
# Out:
# Accident Date                     0
# Day_of_Week                       0
# Junction_Control                  0
# Junction_Detail                   0
# Accident_Severity                 0
# Latitude                          0
# Light_Conditions                  0
# Local_Authority_(District)        0
# Carriageway_Hazards           30088
# Longitude                         0
# Number_of_Casualties              0
# Number_of_Vehicles                0
# Police_Force                      0
# Road_Surface_Conditions           0
# Road_Type                        60
# Speed_limit                       0
# Time                              0
# Urban_or_Rural_Area               0
# Weather_Conditions              230
# Vehicle_Type                      0
# dtype: int64

# %%
mode=df1['Weather_Conditions'].mode()
mode
# Out:
# 0    Fine no high winds
# Name: Weather_Conditions, dtype: object

# %%
df1['Weather_Conditions']=df1['Weather_Conditions'].fillna(mode[0])

# %%
mo1=df1['Road_Type'].mode()
mo1
# Out:
# 0    Single carriageway
# Name: Road_Type, dtype: object

# %%
df1['Road_Type']=df1['Road_Type'].fillna(mo1[0])

# %%
df1=df1.drop('Carriageway_Hazards',axis=1)

# %%
df1.head(2).T
# Out:
#                                                               0  \
# Accident Date                               2021-06-27 00:00:00
# Day_of_Week                                            Saturday
# Junction_Control                   Data missing or out of range
# Junction_Detail             Not at junction or within 20 metres
# Accident_Severity                                         Fatal
# Latitude                                              55.835218
# Light_Conditions                                       Daylight
# Local_Authority_(District)                      North Larkshire
# Longitude                                             -3.912012
# Number_of_Casualties                                          1
# Number_of_Vehicles                                            2
# Police_Force                                        Strathclyde
# Road_Surface_Conditions                                     Dry
# Road_Type                                    Single carriageway
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30429 entries, 0 to 30428
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Accident Date               30429 non-null  datetime64[ns]
#  1   Day_of_Week                 30429 non-null  object
#  2   Junction_Control            30429 non-null  object
#  3   Junction_Detail             30429 non-null  object
#  4   Accident_Severity           30429 non-null  object
#  5   Latitude                    30429 non-null  float64
#  6   Light_Conditions            30429 non-null  object
#  7   Local_Authority_(District)  30429 non-null  object
#  8   Longitude                   30429 non-null  float64
#  9   Number_of_Casualties        30429 non-null  int64
#  10  Number_of_Vehicles          30429 non-null  int64
#  11  Police_Force                30429 non-null  object
#  12  Road_Surface_Conditions     30429 non-null  object
# ...

# %%
df1.isnull().sum()
# Out:
# Accident Date                 0
# Day_of_Week                   0
# Junction_Control              0
# Junction_Detail               0
# Accident_Severity             0
# Latitude                      0
# Light_Conditions              0
# Local_Authority_(District)    0
# Longitude                     0
# Number_of_Casualties          0
# Number_of_Vehicles            0
# Police_Force                  0
# Road_Surface_Conditions       0
# Road_Type                     0
# Speed_limit                   0
# Time                          0
# Urban_or_Rural_Area           0
# Weather_Conditions            0
# Vehicle_Type                  0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
df1.shape
# Out:
# (30429, 19)

# %%
df1['Accident Date'].value_counts()
# Out:
# Accident Date
# 2021-12-04    135
# 2021-10-09    131
# 2021-05-01    130
# 2021-10-02    127
# 2021-11-12    123
#              ...
# 2022-11-24      1
# 2022-12-11      1
# 2022-01-18      1
# 2022-10-08      1
# 2022-01-19      1
# Name: count, Length: 482, dtype: int64

# %%
df1['Year']=df1['Accident Date'].dt.year

# %%
df1['Month']=df1['Accident Date'].dt.month

# %%
df1['Day']=df1['Accident Date'].dt.day

# %%
df1.head(1).T
# Out:
#                                                               0
# Accident Date                               2021-06-27 00:00:00
# Day_of_Week                                            Saturday
# Junction_Control                   Data missing or out of range
# Junction_Detail             Not at junction or within 20 metres
# Accident_Severity                                         Fatal
# Latitude                                              55.835218
# Light_Conditions                                       Daylight
# Local_Authority_(District)                      North Larkshire
# Longitude                                             -3.912012
# Number_of_Casualties                                          1
# Number_of_Vehicles                                            2
# Police_Force                                        Strathclyde
# Road_Surface_Conditions                                     Dry
# Road_Type                                    Single carriageway
# ...

# %%
obj=df1.select_dtypes('object').columns
obj
# Out:
# Index(['Day_of_Week', 'Junction_Control', 'Junction_Detail',
#        'Accident_Severity', 'Light_Conditions', 'Local_Authority_(District)',
#        'Police_Force', 'Road_Surface_Conditions', 'Road_Type', 'Time',
#        'Urban_or_Rural_Area', 'Weather_Conditions', 'Vehicle_Type'],
#       dtype='object')

# %%
c=[]
for l in obj:
    v=df1[l].value_counts()
    c.append(v)

c
# Out:
# [Day_of_Week
#  Friday       5004
#  Wednesday    4542
#  Thursday     4533
#  Tuesday      4529
#  Saturday     4155
#  Monday       4144
#  Sunday       3522
#  Name: count, dtype: int64,
#  Junction_Control
#  Give way or uncontrolled               15553
#  Data missing or out of range            8927
#  Auto traffic signal                     5090
#  Not at junction or within 20 metres      750
#  Stop sign                                 86
#  Authorised person                         23
#  Name: count, dtype: int64,
#  Junction_Detail
#  T or staggered junction                12350
#  Not at junction or within 20 metres     9663
#  Crossroads                              4567
#  Roundabout                              1559
#  Private drive or entrance                785
#  Other junction                           501
#  More than 4 arms (not roundabout)        381
#  Mini-roundabout                          361
#  Slip road                                262
# ...

# %%
df1.to_csv('clean_dt_acc.csv')

# %%
df1.head(1)
# Out:
#   Accident Date Day_of_Week              Junction_Control  \
# 0    2021-06-27    Saturday  Data missing or out of range
#
#                        Junction_Detail Accident_Severity   Latitude  \
# 0  Not at junction or within 20 metres             Fatal  55.835218
#
#   Light_Conditions Local_Authority_(District)  Longitude  \
# 0         Daylight            North Larkshire  -3.912012
#
#    Number_of_Casualties  ...  Road_Surface_Conditions           Road_Type  \
# 0                     1  ...                      Dry  Single carriageway
#
#   Speed_limit      Time  Urban_or_Rural_Area  Weather_Conditions Vehicle_Type  \
# 0          60  09:35:00                Rural  Fine no high winds          Car
#
#    Year Month  Day
# 0  2021     6   27
#
# [1 rows x 22 columns]
